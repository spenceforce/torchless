# %% [raw]
# ---
# title: "The cornerstone of training"
# execute:
#   enabled: true
# ---

# %% [markdown]
# Let's start with a simple function $f(x) = 1$. If we plot this function, we get a horizontal line.

# %%
#| context: output
import matplotlib.pyplot as plt
plt.axhline(1)
ax = plt.gca()
_ = ax.set_ylim([0, 2])
